# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import string

# Character set
CHARS = string.ascii_uppercase + string.digits
CHAR_TO_ID = {c: i + 1 for i, c in enumerate(CHARS)}
ID_TO_CHAR = {i + 1: c for i, c in enumerate(CHARS)}
NUM_CLASSES = len(CHARS) + 1  # +1 for CTC blank token
# Out:
# 2025-05-05 20:57:20.203083: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746503840.215527    8970 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746503840.219283    8970 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746503840.230005    8970 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746503840.230019    8970 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746503840.230020    8970 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746503840.230022    8970 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-05 20:57:20.233756: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("Memory growth enabled")
    except RuntimeError as e:
        print("Error setting memory growth:", e)

tf.debugging.set_log_device_placement(True)
# Out:
# Memory growth enabled

# %%
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')

# %%
class LicensePlateModel(tf.keras.Model):
    def __init__(self):
        super().__init__()
        base_model = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(60, 160, 3))
        self.cnn = tf.keras.Sequential([
            base_model,
            layers.Reshape((-1, base_model.output_shape[-1]))  # (B, width, channels)
        ])
        self.bilstm = tf.keras.Sequential([
            layers.Bidirectional(layers.LSTM(128, return_sequences=True)),
            layers.Bidirectional(layers.LSTM(128, return_sequences=True))
        ])
        self.classifier = layers.Dense(NUM_CLASSES)

    def call(self, images, training=False):
        x = self.cnn(images)
        x = self.bilstm(x)
        return self.classifier(x)

# %%
class CTCLossLayer(tf.keras.layers.Layer):
    def call(self, y_true, y_pred):
        batch_len = tf.cast(tf.shape(y_true)[0], dtype=tf.int64)
        input_len = tf.cast(tf.shape(y_pred)[1], dtype=tf.int64)
        label_len = tf.cast(tf.math.count_nonzero(y_true, axis=-1), dtype=tf.int64)
        input_lengths = input_len * tf.ones(shape=(batch_len, 1), dtype=tf.int64)
        label_lengths = label_len

        loss = tf.keras.backend.ctc_batch_cost(y_true, y_pred, input_lengths, label_lengths)
        return loss

# %%
def create_training_model():
    image_input = layers.Input(shape=(60, 160, 3), name="image")
    label_input = layers.Input(shape=(None,), dtype="int32", name="label")

    model = LicensePlateModel()
    logits = model(image_input)
    loss = CTCLossLayer()(label_input, logits)

    return tf.keras.Model(inputs=[image_input, label_input], outputs=loss)

# %%
def create_prediction_model():
    image_input = layers.Input(shape=(60, 160, 3), name="image")
    model = LicensePlateModel()
    logits = model(image_input)
    return tf.keras.Model(inputs=image_input, outputs=logits)

# %%
from captcha.image import ImageCaptcha
from datasets import Dataset
import random
import string
from PIL import Image

# Same charset
CHARS = string.ascii_uppercase + string.digits
CHAR_TO_ID = {c: i + 1 for i, c in enumerate(CHARS)}
BLANK_TOKEN = 0

def create_captcha_dataset(size=100):
    generator = ImageCaptcha(width=160, height=60)
    data = []
    for _ in range(size):
        label = ''.join(random.choices(CHARS, k=5))
        img = generator.generate_image(label).convert("RGB")
        data.append({'image': img, 'label': label})
    return Dataset.from_list(data)

train_dataset = create_captcha_dataset(500)
val_dataset = create_captcha_dataset(100)

# %%
import tensorflow as tf
import numpy as np

# Label tokenizer
def encode_label(text):
    return [CHAR_TO_ID[c] for c in text]

# Image preprocessing
def process_example(example, augment=False):
    img = example["image"]
    img = img.resize((160, 60))  # Resize if needed
    img = np.array(img).astype("float32") / 255.0  # Normalize to [0,1]
    img = (img - [0.485, 0.456, 0.406]) / [0.229, 0.224, 0.225]  # Standardize
    label = encode_label(example["label"])
    return img, label

def tf_map_fn(example):
    img, label = tf.py_function(
        func=process_example,
        inp=[example],
        Tout=(tf.float32, tf.int32)
    )
    img.set_shape((60, 160, 3))
    label.set_shape([None])
    return {"image": img, "label": label}

# %%
def build_tf_dataset(dataset, batch_size=32, shuffle=True):
    def gen():
        for ex in dataset:
            yield process_example(ex)

    def tf_process(img, label):
        img = tf.convert_to_tensor(img, dtype=tf.float32)
        label = tf.convert_to_tensor(label, dtype=tf.int32)
        return {"image": img, "label": label}

    output_signature = (
        tf.TensorSpec(shape=(60, 160, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None,), dtype=tf.int32)
    )

    ds = tf.data.Dataset.from_generator(gen, output_signature=output_signature)
    ds = ds.map(tf_process, num_parallel_calls=tf.data.AUTOTUNE)
    
    if shuffle:
        ds = ds.shuffle(512)
    
    ds = ds.padded_batch(
        batch_size,
        padded_shapes={"image": [60, 160, 3], "label": [None]},
        padding_values={"image": 0.0, "label": BLANK_TOKEN}
    )
    return ds.prefetch(tf.data.AUTOTUNE)

# %%
# train_tfds = build_tf_dataset(train_dataset)
# val_tfds = build_tf_dataset(val_dataset, shuffle=False)

# %%
class CTCLossTrainer(tf.keras.Model):
    def __init__(self, base_model):
        super().__init__()
        self.base_model = base_model
        self.loss_fn = tf.keras.backend.ctc_batch_cost

    def train_step(self, data):
        x, y_true = data["image"], data["label"]
        with tf.GradientTape() as tape:
            y_pred = self.base_model(x, training=True)

            time_steps = tf.cast(tf.shape(y_pred)[1], tf.int64)
            input_len = tf.fill([tf.shape(y_pred)[0], 1], time_steps)

            label_len = tf.math.count_nonzero(y_true, axis=-1, keepdims=True, dtype=tf.int64)

            loss = self.loss_fn(y_true, y_pred, input_len, label_len)

        gradients = tape.gradient(loss, self.base_model.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.base_model.trainable_variables))
        return {"loss": tf.reduce_mean(loss)}

    def test_step(self, data):
        x, y_true = data["image"], data["label"]
        y_pred = self.base_model(x, training=True)

        time_steps = tf.cast(tf.shape(y_pred)[1], tf.int64)
        input_len = tf.fill([tf.shape(y_pred)[0], 1], time_steps)

        label_len = tf.math.count_nonzero(y_true, axis=-1, keepdims=True, dtype=tf.int64)

        loss = self.loss_fn(y_true, y_pred, input_len, label_len)


        return {"loss": tf.reduce_mean(loss)}

# %%
# base_model = create_prediction_model()
# model = CTCLossTrainer(base_model)

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4))

# model.fit(train_tfds, validation_data=val_tfds, epochs=20)

# %%
from tensorflow import keras

model = keras.models.load_model("models/ctc_model_full.keras", compile=False)

# %%
def build_model():
    inputs = layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3), name="image")
    x = layers.GaussianNoise(0.05)(inputs)
    
    # Initial CNN layers
    x = layers.Conv2D(32, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D((2, 2))(x)  # 100x30
    
    # Residual block 1 with proper dimension matching
    def residual_block(input_tensor, filters):
        # Main path
        x = layers.Conv2D(filters, 3, padding='same', use_bias=False)(input_tensor)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        x = layers.Conv2D(filters, 3, padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        
        # Residual connection with matching dimensions
        residual = layers.Conv2D(filters, 1)(input_tensor)  # No stride needed
        residual = layers.BatchNormalization()(residual)
        
        x = layers.add([x, residual])
        x = layers.ReLU()(x)
        return layers.MaxPooling2D((2, 2))(x)  # Downsample after addition
    
    x = residual_block(x, 64)  # 50x15
    x = residual_block(x, 128) # 25x15
    
    # Final CNN layers with corrected dimensions
    x = layers.Conv2D(256, (3, 3), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D((2, 2))(x)  # Now outputs 12x7
    
    # Calculate feature dimension
    time_steps = 12
    features_per_step = 3 * 256  # 7 width * 256 channels
    
    x = layers.Reshape((time_steps, features_per_step))(x)
    
    # RNN section
    x = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(x)
    x = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(x)
    
    logits = layers.Dense(NUM_CLASSES, activation="linear", name="logits")(x)
    return tf.keras.Model(inputs, logits)

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import tensorflow as tf
import random

# -- Reuse constants from training
IMG_WIDTH, IMG_HEIGHT = 200, 60
CHARS = string.ascii_uppercase + string.digits
ID_TO_CHAR = {i + 1: c for i, c in enumerate(CHARS)}  # CTC labels start at 1
ID_TO_CHAR[0] = ''  # blank token

# -- Helper to decode prediction
def decode_prediction(pred):
    pred_ids = tf.argmax(pred, axis=-1).numpy()
    decoded = []
    for seq in pred_ids:
        text = []
        prev = -1
        for idx in seq:
            if idx != prev and idx != 0:
                text.append(ID_TO_CHAR.get(idx, ''))
            prev = idx
        decoded.append(''.join(text))
    return decoded

# -- Load model
def load_trained_model(weights_path):
    model = build_model()
    model.load_weights(weights_path)
    return model

# -- Plot random 5 images from dataset
def show_predictions(model, dataset, num_samples=5):
    # Unbatch and collect samples
    samples = list(dataset.unbatch().take(100))
    chosen = random.sample(samples, num_samples)

    plt.figure(figsize=(15, 4))
    for i, sample in enumerate(chosen):
        img = sample["image"].numpy()
        label = sample["label"].numpy()
        label_len = sample["label_len"].numpy()

        img_batch = tf.expand_dims(img, 0)  # Add batch dim
        pred = model(img_batch, training=False)
        decoded = decode_prediction(pred)[0]

        label_text = ''.join([ID_TO_CHAR[c] for c in label[:label_len]])

        plt.subplot(1, num_samples, i + 1)
        plt.imshow(img)
        plt.title(f"GT: {label_text}\nPred: {decoded}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
model = load_trained_model("checkpoints/license_plate_best.weights.h5")
# Out:
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomNormalV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Qr in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op MatrixDiagPartV3 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sign in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Transpose in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.284342: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.284359: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.291268: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.291283: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.295022: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.295035: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.297150: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.297159: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.299065: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.299075: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.301017: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.301027: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.309329: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.309346: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.312591: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.312603: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.314726: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.314737: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.316884: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.316896: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.318817: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.318827: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.326082: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.326097: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.329973: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.329984: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.332213: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.332222: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.334168: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.334178: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.336091: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.336099: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.343223: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.343251: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.349125: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.349149: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.353218: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.353232: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.356708: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.356732: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.359639: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.359660: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.362619: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.362634: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.374514: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.374536: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.378876: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.378890: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.381581: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.381594: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.384138: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.384150: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.386770: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.386783: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.395591: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.395613: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.401696: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.401710: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.404362: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.404372: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.406777: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.406786: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.409032: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.409041: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.414759: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.414770: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.416820: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.416829: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.419670: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.419679: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.421610: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.421619: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.423759: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.423770: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.426135: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.426148: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.435396: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.435408: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.438442: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.438454: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.440936: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.440946: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.443020: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.443028: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.444988: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.444997: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.449620: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.449631: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.453324: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.453334: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.456721: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.456730: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.462427: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.462437: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ConcatV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomNormalV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Qr in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op MatrixDiagPartV3 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sign in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Transpose in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ConcatV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# ...
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomNormalV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Qr in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op MatrixDiagPartV3 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sign in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Transpose in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ConcatV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomNormalV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Qr in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op MatrixDiagPartV3 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sign in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Transpose in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ConcatV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op FloorMod in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomGetKeyCounter in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op StatelessRandomUniformV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.485388: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.485410: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.490327: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.490341: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.496307: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.496326: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.518477: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.518494: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.522987: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.523002: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.526233: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.526243: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.530000: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.530013: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.533291: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.533300: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.538517: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.538529: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.560381: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.560397: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.564586: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.564596: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.569493: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.569503: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.589907: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.589925: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.594485: I tensorflow/core/common_runtime/placer.cc:162] resource_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-05-05 22:03:40.594499: I tensorflow/core/common_runtime/placer.cc:162] VarHandleOp: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 model = load_trained_model("checkpoints/license_plate_best.weights.h5")
#
# Cell In[19], line 30, in load_trained_model(weights_path)
#      28 def load_trained_model(weights_path):
#      29     model = build_model()
# ---> 30     model.load_weights(weights_path)
#      31     return model
#
# File ~/anaconda3/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/anaconda3/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:631, in _raise_loading_failure(error_msgs, warn_only)
#     629     warnings.warn(msg)
#     630 else:
# --> 631     raise ValueError(msg)
#
# ValueError: A total of 21 objects could not be loaded. Example error message for object <Conv2D name=conv2d_8, built=True>:
#
# Layer 'conv2d_8' expected 1 variables, but received 0 variables during loading. Expected: ['kernel']
#
# List of objects that could not be loaded:
# [<Conv2D name=conv2d_8, built=True>, <BatchNormalization name=batch_normalization_8, built=True>, <Conv2D name=conv2d_9, built=True>, <BatchNormalization name=batch_normalization_9, built=True>, <Conv2D name=conv2d_10, built=True>, <Conv2D name=conv2d_11, built=True>, <BatchNormalization name=batch_normalization_10, built=True>, <BatchNormalization name=batch_normalization_11, built=True>, <Conv2D name=conv2d_12, built=True>, <BatchNormalization name=batch_normalization_12, built=True>, <Conv2D name=conv2d_13, built=True>, <Conv2D name=conv2d_14, built=True>, <BatchNormalization name=batch_normalization_13, built=True>, <BatchNormalization name=batch_normalization_14, built=True>, <Conv2D name=conv2d_15, built=True>, <BatchNormalization name=batch_normalization_15, built=True>, <LSTMCell name=lstm_cell, built=True>, <LSTMCell name=lstm_cell, built=True>, <LSTMCell name=lstm_cell, built=True>, <LSTMCell name=lstm_cell, built=True>, <Dense name=logits, built=True>]
